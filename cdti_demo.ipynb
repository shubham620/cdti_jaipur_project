# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham620/cdti_jaipur_project/blob/main/cdti_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

# %%
# Load CSV file
df = pd.read_csv("demo_input_data_3.csv")

# Display the raw data
print("RAW INPUT DATA:")
df.head()
# Out:
# RAW INPUT DATA:
#     id                                               text     source  \
# 0  1_1            Crowd gathering reported near City Mall     social
# 1  1_2  Police received call regarding crowd near City...  emergency
# 2  2_1       Fire and smoke reported near Railway Station     social
# 3  2_2         Fire brigade dispatched to Railway Station   official
# 4  3_1        Medical emergency reported at Metro Station     social
#
#          time                 location
# 0  9:00:00 AM        City Mall, Jaipur
# 1  9:04:00 AM        City Mall, Jaipur
# 2  9:10:00 AM  Railway Station, Jaipur
# 3  9:14:00 AM  Railway Station, Jaipur
# 4  9:20:00 AM    Metro Station, Jaipur

# %%
def clean_text(text):
    text = text.lower()                     # convert to lowercase
    text = re.sub(r"[^a-zA-Z\s]", "", text) # remove special characters
    text = re.sub(r"\s+", " ", text)        # remove extra spaces
    return text.strip()

# %%
# Apply text cleaning
df["clean_text"] = df["text"].apply(clean_text)

# Show cleaned text
print("CLEANED DATA:")
df[["id", "text", "clean_text"]]
# Out:
# CLEANED DATA:
#         id                                               text  \
# 0      1_1            Crowd gathering reported near City Mall
# 1      1_2  Police received call regarding crowd near City...
# 2      2_1       Fire and smoke reported near Railway Station
# 3      2_2         Fire brigade dispatched to Railway Station
# 4      3_1        Medical emergency reported at Metro Station
# ..     ...                                                ...
# 195   98_2               Electric department restoring supply
# 196   99_1           Fire reported near Civil Lines warehouse
# 197   99_2                            Fire brigade responding
# 198  100_1        Traffic disruption reported near NH-21 toll
# 199  100_2            Traffic police clearing toll congestion
#
#                                             clean_text
# 0              crowd gathering reported near city mall
# 1    police received call regarding crowd near city...
# 2         fire and smoke reported near railway station
# 3           fire brigade dispatched to railway station
# 4          medical emergency reported at metro station
# ..                                                 ...
# 195               electric department restoring supply
# 196           fire reported near civil lines warehouse
# 197                            fire brigade responding
# 198           traffic disruption reported near nh toll
# 199            traffic police clearing toll congestion
#
# [200 rows x 3 columns]

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# %%
# Load a lightweight sentence embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
# Convert cleaned text into embeddings (numeric meaning)
embeddings = model.encode(df["clean_text"].tolist())

# Check embedding shape
print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (200, 384)

# %%
# Store embeddings inside dataframe
df["embedding"] = embeddings.tolist()

df[["id", "clean_text"]].head()
# Out:
#     id                                         clean_text
# 0  1_1            crowd gathering reported near city mall
# 1  1_2  police received call regarding crowd near city...
# 2  2_1       fire and smoke reported near railway station
# 3  2_2         fire brigade dispatched to railway station
# 4  3_1        medical emergency reported at metro station

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Convert list of embeddings to numpy array
X = np.array(df["embedding"].tolist())

# Compute cosine similarity between all messages
similarity_matrix = cosine_similarity(X)

# %%
# Convert similarity to distance
distance_matrix = 1 - similarity_matrix

# Fix floating point negatives (important)
distance_matrix[distance_matrix < 0] = 0

# %%
# Apply DBSCAN clustering
dbscan = DBSCAN(
    eps=0.3,          # similarity threshold (tunable)
    min_samples=2,    # minimum messages to form an event
    metric="precomputed"
)

df["event_id"] = dbscan.fit_predict(distance_matrix)

# %%
# Display messages grouped by event
for event in df["event_id"].unique():
    print(f"\nEVENT {event}:")
    display(df[df["event_id"] == event][["id", "text", "source", "location"]])
# Out:
# EVENT 0:
#        id                                               text     source  \
# 0     1_1            Crowd gathering reported near City Mall     social
# 1     1_2  Police received call regarding crowd near City...  emergency
# 16    9_1         Crowd forming near Airport Road checkpoint     social
# 28   15_1       Public gathering reported near Metro Station     social
# 29   15_2      Authorities monitoring crowd at Metro Station       news
# 40   21_1    Crowd gathering reported near City Mall parking     social
# 41   21_2     Police monitoring crowd near City Mall parking   official
# 56   29_1          Crowd forming near Metro Station entrance     social
# 68   35_1        Public gathering reported near Airport Road     social
# 69   35_2     Authorities monitoring crowd near Airport Road       news
# 84   43_1       Crowd forming near Railway Station exit gate     social
# 85   43_2                    Railway security managing crowd   official
# 96   49_1  Crowd gathering reported near Vaishali Nagar m...     social
# 97   49_2             Police deployed to manage market crowd   official
# 106  54_1    Public gathering reported near City Mall gate 2     social
# 107  54_2    Authorities monitoring gathering near City Mall       news
# 120  61_1   Crowd gathering reported near Civil Lines market     social
# 121  61_2      Police managing crowd near Civil Lines market   official
# 134  68_1  Crowd gathering reported near Metro Station pl...     social
# 144  73_1  Crowd gathering reported near Vaishali Nagar m...     social
# 145  73_2             Police deployed to manage market crowd   official
# 160  81_1        Crowd forming near Bus Stand ticket counter     social
# 161  81_2            Authorities managing crowd at Bus Stand   official
# 172  87_1  Crowd gathering reported near Vaishali Nagar s...     social
# 173  87_2     Police managing crowd at Vaishali Nagar square   official
# 182  92_1       Crowd forming near Airport terminal entrance     social
# 183  92_2                    Airport security managing crowd   official
# 192  97_1  Public gathering reported near Metro Station exit     social
#
#                     location
# 0          City Mall, Jaipur
# 1          City Mall, Jaipur
# 16      Airport Road, Jaipur
# 28     Metro Station, Jaipur
# 29     Metro Station, Jaipur
# 40         City Mall, Jaipur
# 41         City Mall, Jaipur
# 56     Metro Station, Jaipur
# 68      Airport Road, Jaipur
# 69      Airport Road, Jaipur
# 84   Railway Station, Jaipur
# 85   Railway Station, Jaipur
# 96    Vaishali Nagar, Jaipur
# 97    Vaishali Nagar, Jaipur
# 106        City Mall, Jaipur
# 107        City Mall, Jaipur
# 120      Civil Lines, Jaipur
# 121      Civil Lines, Jaipur
# 134    Metro Station, Jaipur
# 144   Vaishali Nagar, Jaipur
# 145   Vaishali Nagar, Jaipur
# 160        Bus Stand, Jaipur
# 161        Bus Stand, Jaipur
# 172   Vaishali Nagar, Jaipur
# 173   Vaishali Nagar, Jaipur
# 182     Airport Road, Jaipur
# 183     Airport Road, Jaipur
# 192    Metro Station, Jaipur
# EVENT 1:
#        id                                               text     source  \
# 2     2_1       Fire and smoke reported near Railway Station     social
# 3     2_2         Fire brigade dispatched to Railway Station   official
# 18   10_1  Fire reported in commercial building near Civi...     social
# 19   10_2  Fire services responding to incident in Civil ...  emergency
# 42   22_1  Fire alarm triggered near Railway Station plat...     social
# 43   22_2  Fire services inspecting alarm near Railway St...   official
# 58   30_1   Fire reported in residential area of Civil Lines     social
# 59   30_2    Fire brigade responding to Civil Lines incident  emergency
# 82   42_1          Fire alarm reported near Airport terminal     social
# 83   42_2          Fire services checking alarm near airport   official
# 98   50_1              Fire reported in warehouse near NH-21     social
# 99   50_2          Fire brigade responding to warehouse fire  emergency
# 122  62_1         Fire reported in small shop near Bus Stand     social
# 123  62_2               Fire brigade responding to shop fire  emergency
# 136  69_1      Fire alarm triggered near Airport Road office     social
# 137  69_2                     Fire services inspecting alarm   official
# 148  75_1       Fire reported in parking area near City Mall     social
# 149  75_2            Fire brigade responding to parking fire  emergency
# 162  82_1    Fire alarm reported near Railway Station office     social
# 163  82_2                      Fire services verifying alarm   official
# 174  88_1           Fire reported in shop near Metro Station     social
# 175  88_2               Fire brigade responding to shop fire  emergency
# 184  93_1  Fire alarm reported near University admin buil...     social
# 185  93_2                      Fire services verifying alarm   official
# 196  99_1           Fire reported near Civil Lines warehouse     social
# 197  99_2                            Fire brigade responding  emergency
#
#                     location
# 2    Railway Station, Jaipur
# 3    Railway Station, Jaipur
# 18       Civil Lines, Jaipur
# 19       Civil Lines, Jaipur
# 42   Railway Station, Jaipur
# 43   Railway Station, Jaipur
# 58       Civil Lines, Jaipur
# 59       Civil Lines, Jaipur
# 82      Airport Road, Jaipur
# 83      Airport Road, Jaipur
# 98             NH-21, Jaipur
# 99             NH-21, Jaipur
# 122        Bus Stand, Jaipur
# 123        Bus Stand, Jaipur
# 136     Airport Road, Jaipur
# 137     Airport Road, Jaipur
# 148        City Mall, Jaipur
# 149        City Mall, Jaipur
# 162  Railway Station, Jaipur
# 163  Railway Station, Jaipur
# 174    Metro Station, Jaipur
# 175    Metro Station, Jaipur
# 184  University Road, Jaipur
# 185  University Road, Jaipur
# 196      Civil Lines, Jaipur
# 197      Civil Lines, Jaipur
# EVENT 2:
#         id                                               text     source  \
# 4      3_1        Medical emergency reported at Metro Station     social
# 5      3_2  Ambulance responding to medical emergency at M...  emergency
# 6      4_1               Traffic disruption reported on NH-21     social
# 7      4_2  Traffic police confirms vehicle breakdown on N...   official
# 22    12_1    Medical assistance requested at Railway Station     social
# 23    12_2              Medical staff reached Railway Station   official
# 32    17_1                    Road accident reported on NH-21     social
# 33    17_2    Emergency response dispatched to NH-21 accident  emergency
# 38    20_1         Medical emergency reported at Airport Road     social
# 39    20_2               Ambulance dispatched to Airport Road  emergency
# 44    23_1          Medical emergency reported near Bus Stand     social
# 45    23_2                  Ambulance dispatched to Bus Stand  emergency
# 60    31_1                 Traffic accident reported on NH-21     social
# 61    31_2    Emergency services responding to NH-21 accident  emergency
# 62    32_1  Medical assistance requested near Railway Station     social
# 63    32_2         Medical team dispatched to Railway Station   official
# 72    37_1          Road accident reported near Metro Station     social
# 73    37_2  Emergency response sent to Metro Station accident  emergency
# 78    40_1          Medical emergency reported near City Mall     social
# 79    40_2                  Ambulance dispatched to City Mall  emergency
# 92    47_1    Medical emergency reported near University Road     social
# 93    47_2                  Emergency medical team dispatched  emergency
# 102   52_1            Medical emergency reported at Bus Stand     social
# 103   52_2                  Ambulance dispatched to Bus Stand  emergency
# 110   56_1        Road accident reported near Railway Station     social
# 111   56_2         Emergency response sent to Railway Station  emergency
# 116   59_1   Medical emergency reported near Airport terminal     social
# 117   59_2           Ambulance dispatched to airport terminal  emergency
# 124   63_1       Traffic disruption reported on NH-21 flyover     social
# 126   64_1    Medical emergency reported near Mansarovar park     social
# 127   64_2                      Emergency services dispatched  emergency
# 139   70_2           Emergency response sent to accident site  emergency
# 140   71_1   Medical emergency reported near Bus Stand gate 3     social
# 141   71_2           Ambulance dispatched to Bus Stand gate 3  emergency
# 152   77_1   Medical emergency reported near Civil Lines park     social
# 153   77_2                  Emergency medical team dispatched  emergency
# 166   84_1    Medical emergency reported near Airport parking     social
# 167   84_2            Ambulance dispatched to airport parking  emergency
# 177   89_2                      Emergency response dispatched  emergency
# 178   90_1  Medical emergency reported near Railway Statio...     social
# 179   90_2                   Medical team attending emergency   official
# 188   95_1  Medical emergency reported near Mansarovar market     social
# 189   95_2                               Ambulance dispatched  emergency
# 198  100_1        Traffic disruption reported near NH-21 toll     social
#
#                     location
# 4      Metro Station, Jaipur
# 5      Metro Station, Jaipur
# 6              NH-21, Jaipur
# 7              NH-21, Jaipur
# 22   Railway Station, Jaipur
# 23   Railway Station, Jaipur
# 32             NH-21, Jaipur
# 33             NH-21, Jaipur
# 38      Airport Road, Jaipur
# 39      Airport Road, Jaipur
# 44         Bus Stand, Jaipur
# 45         Bus Stand, Jaipur
# 60             NH-21, Jaipur
# 61             NH-21, Jaipur
# 62   Railway Station, Jaipur
# 63   Railway Station, Jaipur
# 72     Metro Station, Jaipur
# 73     Metro Station, Jaipur
# 78         City Mall, Jaipur
# 79         City Mall, Jaipur
# 92   University Road, Jaipur
# 93   University Road, Jaipur
# 102        Bus Stand, Jaipur
# 103        Bus Stand, Jaipur
# 110  Railway Station, Jaipur
# 111  Railway Station, Jaipur
# 116     Airport Road, Jaipur
# 117     Airport Road, Jaipur
# 124            NH-21, Jaipur
# 126       Mansarovar, Jaipur
# 127       Mansarovar, Jaipur
# 139      Civil Lines, Jaipur
# 140        Bus Stand, Jaipur
# 141        Bus Stand, Jaipur
# 152      Civil Lines, Jaipur
# 153      Civil Lines, Jaipur
# 166     Airport Road, Jaipur
# 167     Airport Road, Jaipur
# 177        Bus Stand, Jaipur
# 178  Railway Station, Jaipur
# 179  Railway Station, Jaipur
# 188       Mansarovar, Jaipur
# 189       Mansarovar, Jaipur
# 198            NH-21, Jaipur
# EVENT 3:
#        id                                               text    source  \
# 8     5_1     Waterlogging reported in Mansarovar after rain    social
# 9     5_2    Municipal team deployed to inspect waterlogging  official
# 24   13_1  Flood risk reported in low-lying area of Mansa...    social
# 25   13_2      Officials inspecting flood risk in Mansarovar  official
# 48   25_1  Waterlogging reported in low-lying Mansarovar ...    social
# 49   25_2  Municipal team addressing waterlogging in Mans...  official
# 64   33_1  Flood risk reported near drainage area in Mans...    social
# 65   33_2  Officials assessing drainage overflow in Mansa...  official
# 94   48_1  Waterlogging reported after rain near Metro St...    social
# 95   48_2             Municipal team inspecting waterlogging  official
# 108  55_1     Heavy rainfall reported in Mansarovar sector 3    social
# 142  72_1    Waterlogging reported near Railway Station road    social
# 143  72_2                 Municipal team inspecting drainage  official
# 154  78_1   Heavy rainfall reported near Mansarovar sector 7    social
# 168  85_1        Waterlogging reported near Civil Lines road    social
# 169  85_2             Municipal team inspecting waterlogging  official
#
#                     location
# 8         Mansarovar, Jaipur
# 9         Mansarovar, Jaipur
# 24        Mansarovar, Jaipur
# 25        Mansarovar, Jaipur
# 48        Mansarovar, Jaipur
# 49        Mansarovar, Jaipur
# 64        Mansarovar, Jaipur
# 65        Mansarovar, Jaipur
# 94     Metro Station, Jaipur
# 95     Metro Station, Jaipur
# 108       Mansarovar, Jaipur
# 142  Railway Station, Jaipur
# 143  Railway Station, Jaipur
# 154       Mansarovar, Jaipur
# 168      Civil Lines, Jaipur
# 169      Civil Lines, Jaipur
# EVENT 4:
#        id                                               text    source  \
# 10    6_1  Unverified bomb threat rumor reported at Bus S...    social
# 11    6_2        Police deny bomb threat rumors at Bus Stand  official
# 26   14_1      Suspicious bag rumor circulating at Bus Stand    social
# 27   14_2             Police confirms no threat at Bus Stand  official
# 50   26_1  Unverified blast rumor circulating near Airpor...    social
# 51   26_2     Authorities deny blast rumor near Airport Road  official
# 66   34_1      Suspicious object rumor reported at Bus Stand    social
# 67   34_2              Police confirm no threat at Bus Stand  official
# 112  57_1   Suspicious bag rumor reported near Metro Station    social
# 113  57_2          Police confirm no threat at Metro Station  official
#
#                   location
# 10       Bus Stand, Jaipur
# 11       Bus Stand, Jaipur
# 26       Bus Stand, Jaipur
# 27       Bus Stand, Jaipur
# 50    Airport Road, Jaipur
# 51    Airport Road, Jaipur
# 66       Bus Stand, Jaipur
# 67       Bus Stand, Jaipur
# 112  Metro Station, Jaipur
# 113  Metro Station, Jaipur
# EVENT 5:
#        id                                               text    source  \
# 12    7_1        Small protest reported near University Road    social
# 13    7_2  Authorities monitoring peaceful protest near U...      news
# 34   18_1  Protest gathering reported near University campus    social
# 35   18_2              Police monitoring protest near campus  official
# 52   27_1    Protest gathering reported near University gate    social
# 53   27_2  Police maintaining order at University Road pr...  official
# 74   38_1         Small protest reported near college campus    social
# 75   38_2                 Police monitoring peaceful protest  official
# 130  66_1  Public protest reported near University Road j...    social
# 131  66_2                Police monitoring protest situation  official
# 156  79_1  Protest gathering reported near University mai...    social
# 157  79_2     Police monitoring situation at University gate  official
#
#                     location
# 12   University Road, Jaipur
# 13   University Road, Jaipur
# 34   University Road, Jaipur
# 35   University Road, Jaipur
# 52   University Road, Jaipur
# 53   University Road, Jaipur
# 74   University Road, Jaipur
# 75   University Road, Jaipur
# 130  University Road, Jaipur
# 131  University Road, Jaipur
# 156  University Road, Jaipur
# 157  University Road, Jaipur
# EVENT 6:
#        id                                               text  source  \
# 14    8_1            Power outage reported in Vaishali Nagar  social
# 54   28_1    Power outage reported in Vaishali Nagar block A  social
# 118  60_1   Power outage reported in Vaishali Nagar sector 2  social
# 132  67_1          Power outage reported near City Mall area  social
# 158  80_1     Power outage reported near Metro Station block  social
# 180  91_1  Power failure reported near City Mall service ...  social
# 194  98_1          Power outage reported near Bus Stand area  social
#
#                    location
# 14   Vaishali Nagar, Jaipur
# 54   Vaishali Nagar, Jaipur
# 118  Vaishali Nagar, Jaipur
# 132       City Mall, Jaipur
# 158   Metro Station, Jaipur
# 180       City Mall, Jaipur
# 194       Bus Stand, Jaipur
# EVENT 7:
#        id                                               text    source  \
# 15    8_2  Electricity department confirms maintenance-re...  official
# 31   16_2     Electric department confirms power restoration  official
# 55   28_2    Electric department confirms outage repair work  official
# 71   36_2  Electric department restores power in Civil Lines  official
# 87   44_2               Electric department repairing outage  official
# 105  53_2                 Electric department restores power  official
# 119  60_2      Electric department confirms restoration work  official
# 133  67_2                Electric department restoring power  official
# 147  74_2        Electric department repairing power failure  official
# 159  80_2         Electric department restoring power supply  official
# 171  86_2                 Electric department restores power  official
# 181  91_2                 Electric department restores power  official
# 195  98_2               Electric department restoring supply  official
#
#                     location
# 15    Vaishali Nagar, Jaipur
# 31       Civil Lines, Jaipur
# 55    Vaishali Nagar, Jaipur
# 71       Civil Lines, Jaipur
# 87        Mansarovar, Jaipur
# 105      Civil Lines, Jaipur
# 119   Vaishali Nagar, Jaipur
# 133        City Mall, Jaipur
# 147  University Road, Jaipur
# 159    Metro Station, Jaipur
# 171       Mansarovar, Jaipur
# 181        City Mall, Jaipur
# 195        Bus Stand, Jaipur
# EVENT 8:
#        id                                       text    source  \
# 17    9_2   Security team deployed near Airport Road  official
# 57   29_2  Security team deployed near Metro Station  official
# 101  51_2  Traffic police deployed near Airport Road  official
# 135  68_2  Metro security deployed for crowd control  official
# 193  97_2                     Security team deployed  official
#
#                   location
# 17    Airport Road, Jaipur
# 57   Metro Station, Jaipur
# 101   Airport Road, Jaipur
# 135  Metro Station, Jaipur
# 193  Metro Station, Jaipur
# EVENT 9:
#         id                                               text    source  \
# 20    11_1         Traffic congestion reported near City Mall    social
# 21    11_2  Traffic police managing congestion near City Mall  official
# 46    24_1       Traffic congestion reported near Civil Lines    social
# 81    41_2  Traffic police managing congestion near Bus Stand  official
# 90    46_1  Traffic disruption reported near Civil Lines c...    social
# 91    46_2                 Traffic police clearing disruption  official
# 100   51_1      Traffic congestion reported near Airport Road    social
# 115   58_2                 Traffic police managing congestion  official
# 125   63_2         Traffic police clearing flyover congestion  official
# 138   70_1  Traffic accident reported near Civil Lines cro...    social
# 150   76_1  Traffic congestion reported near Airport Road ...    social
# 151   76_2         Traffic police clearing flyover congestion  official
# 164   83_1    Traffic disruption reported near City Mall exit    social
# 186   94_1  Traffic congestion reported near Civil Lines s...    social
# 187   94_2                 Traffic police clearing congestion  official
# 199  100_2            Traffic police clearing toll congestion  official
#
#                     location
# 20         City Mall, Jaipur
# 21         City Mall, Jaipur
# 46       Civil Lines, Jaipur
# 81         Bus Stand, Jaipur
# 90       Civil Lines, Jaipur
# 91       Civil Lines, Jaipur
# 100     Airport Road, Jaipur
# 115  University Road, Jaipur
# 125            NH-21, Jaipur
# 138      Civil Lines, Jaipur
# 150     Airport Road, Jaipur
# 151     Airport Road, Jaipur
# 164        City Mall, Jaipur
# 186      Civil Lines, Jaipur
# 187      Civil Lines, Jaipur
# 199            NH-21, Jaipur
# EVENT 10:
#       id                                            text  source  \
# 30  16_1       Power fluctuation reported in Civil Lines  social
# 70  36_1  Power fluctuation reported in Civil Lines area  social
#
#                location
# 30  Civil Lines, Jaipur
# 70  Civil Lines, Jaipur
# EVENT 11:
#        id                                         text  source  \
# 36   19_1    Heavy rainfall reported in Vaishali Nagar  social
# 76   39_1    Heavy rainfall reported in Vaishali Nagar  social
# 128  65_1  Heavy rainfall reported near Vaishali Nagar  social
# 190  96_1  Heavy rainfall reported near Vaishali Nagar  social
#
#                    location
# 36   Vaishali Nagar, Jaipur
# 76   Vaishali Nagar, Jaipur
# 128  Vaishali Nagar, Jaipur
# 190  Vaishali Nagar, Jaipur
# EVENT 12:
#        id                                         text    source  \
# 37   19_2  Weather department issues rainfall advisory  official
# 77   39_2  Weather department issues rainfall advisory  official
# 109  55_2       Weather advisory issued for Mansarovar  official
# 129  65_2            Weather department issues warning  official
# 155  78_2      Weather department issues rain advisory  official
# 191  96_2                      Weather advisory issued  official
#
#                    location
# 37   Vaishali Nagar, Jaipur
# 77   Vaishali Nagar, Jaipur
# 109      Mansarovar, Jaipur
# 129  Vaishali Nagar, Jaipur
# 155      Mansarovar, Jaipur
# 191  Vaishali Nagar, Jaipur
# EVENT -1:
#        id                                               text    source  \
# 47   24_2      Traffic police regulating flow at Civil Lines  official
# 104  53_1      Power failure reported in Civil Lines block C    social
# 146  74_1  Power failure reported near University Road ho...    social
# 165  83_2             Traffic police clearing mall exit road  official
# 176  89_1   Traffic accident reported near Bus Stand flyover    social
#
#                     location
# 47       Civil Lines, Jaipur
# 104      Civil Lines, Jaipur
# 146  University Road, Jaipur
# 165        City Mall, Jaipur
# 176        Bus Stand, Jaipur
# EVENT 13:
#        id                                       text  source  \
# 80   41_1        Traffic jam reported near Bus Stand  social
# 114  58_1  Traffic jam reported near University Road  social
#
#                     location
# 80         Bus Stand, Jaipur
# 114  University Road, Jaipur
# EVENT 14:
#        id                                            text  source  \
# 86   44_1    Power outage reported in Mansarovar sector 5  social
# 170  86_1  Power outage reported near Mansarovar sector 1  social
#
#                location
# 86   Mansarovar, Jaipur
# 170  Mansarovar, Jaipur
# EVENT 15:
#       id                                             text    source location
# 88  45_1     Unverified threat message circulating online    social   Jaipur
# 89  45_2  Authorities investigating online threat message  official   Jaipur

# %%
# Remove noise messages (event_id = -1)
events_df = df[df["event_id"] != -1]

# Group messages by event
event_summary = events_df.groupby("event_id").agg(
    message_count=("id", "count"),
    sources=("source", lambda x: list(set(x))),
    locations=("location", lambda x: list(set(x)))
).reset_index()

event_summary
# Out:
#     event_id  message_count                              sources  \
# 0          0             28  [news, social, emergency, official]
# 1          1             26        [social, official, emergency]
# 2          2             44        [social, emergency, official]
# 3          3             16                   [social, official]
# 4          4             10                   [social, official]
# 5          5             12             [news, social, official]
# 6          6              7                             [social]
# 7          7             13                           [official]
# 8          8              5                           [official]
# 9          9             16                   [social, official]
# 10        10              2                             [social]
# 11        11              4                             [social]
# 12        12              6                           [official]
# 13        13              2                             [social]
# 14        14              2                             [social]
# 15        15              2                   [social, official]
#
#                                             locations
# 0   [Airport Road, Jaipur, Railway Station, Jaipur...
# 1   [Airport Road, Jaipur, Bus Stand, Jaipur, Rail...
# 2   [Airport Road, Jaipur, Bus Stand, Jaipur, Rail...
# 3   [Metro Station, Jaipur, Railway Station, Jaipu...
# 4   [Airport Road, Jaipur, Bus Stand, Jaipur, Metr...
# 5                           [University Road, Jaipur]
# 6   [Metro Station, Jaipur, Bus Stand, Jaipur, Vai...
# 7   [Bus Stand, Jaipur, Mansarovar, Jaipur, Univer...
# 8       [Airport Road, Jaipur, Metro Station, Jaipur]
# 9   [Airport Road, Jaipur, Bus Stand, Jaipur, Univ...
# 10                              [Civil Lines, Jaipur]
# 11                           [Vaishali Nagar, Jaipur]
# 12       [Vaishali Nagar, Jaipur, Mansarovar, Jaipur]
# 13       [Bus Stand, Jaipur, University Road, Jaipur]
# 14                               [Mansarovar, Jaipur]
# 15                                           [Jaipur]

# %%
def calculate_credibility(message_count, sources):
    sources = set(sources)

    # Strong confirmation
    if message_count >= 3 and ("official" in sources or "emergency" in sources):
        return "High"

    # News + social but no official confirmation → suspicious
    if "news" in sources and "official" not in sources and "emergency" not in sources:
        return "Low"

    # Multiple reports but only public sources
    if message_count >= 2:
        return "Medium"

    return "Low"

# %%
event_summary["credibility"] = event_summary.apply(
    lambda row: calculate_credibility(row["message_count"], row["sources"]),
    axis=1
)

event_summary
# Out:
#     event_id  message_count                              sources  \
# 0          0             28  [news, social, emergency, official]
# 1          1             26        [social, official, emergency]
# 2          2             44        [social, emergency, official]
# 3          3             16                   [social, official]
# 4          4             10                   [social, official]
# 5          5             12             [news, social, official]
# 6          6              7                             [social]
# 7          7             13                           [official]
# 8          8              5                           [official]
# 9          9             16                   [social, official]
# 10        10              2                             [social]
# 11        11              4                             [social]
# 12        12              6                           [official]
# 13        13              2                             [social]
# 14        14              2                             [social]
# 15        15              2                   [social, official]
#
#                                             locations credibility
# 0   [Airport Road, Jaipur, Railway Station, Jaipur...        High
# 1   [Airport Road, Jaipur, Bus Stand, Jaipur, Rail...        High
# 2   [Airport Road, Jaipur, Bus Stand, Jaipur, Rail...        High
# 3   [Metro Station, Jaipur, Railway Station, Jaipu...        High
# 4   [Airport Road, Jaipur, Bus Stand, Jaipur, Metr...        High
# 5                           [University Road, Jaipur]        High
# 6   [Metro Station, Jaipur, Bus Stand, Jaipur, Vai...      Medium
# 7   [Bus Stand, Jaipur, Mansarovar, Jaipur, Univer...        High
# 8       [Airport Road, Jaipur, Metro Station, Jaipur]        High
# 9   [Airport Road, Jaipur, Bus Stand, Jaipur, Univ...        High
# 10                              [Civil Lines, Jaipur]      Medium
# 11                           [Vaishali Nagar, Jaipur]      Medium
# 12       [Vaishali Nagar, Jaipur, Mansarovar, Jaipur]        High
# 13       [Bus Stand, Jaipur, University Road, Jaipur]      Medium
# 14                               [Mansarovar, Jaipur]      Medium
# 15                                           [Jaipur]      Medium

# %%
def detect_risk_level(texts, locations, message_count):
    text_combined = " ".join(texts).lower()
    locations = " ".join(locations).lower()

    # High-risk keywords & places
    high_risk_keywords = ["fire", "blast", "explosion", "smoke"]
    sensitive_places = ["railway", "bus stand", "station"]

    # Medium-risk keywords & places
    medium_risk_keywords = ["crowd", "gathering", "people"]
    public_places = ["mall", "market"]

    # High risk conditions
    if any(word in text_combined for word in high_risk_keywords):
        return "High"
    if any(place in locations for place in sensitive_places):
        return "High"

    # Medium risk conditions
    if any(word in text_combined for word in medium_risk_keywords):
        return "Medium"
    if any(place in locations for place in public_places):
        return "Medium"

    # Low risk otherwise
    return "Low"

# %%
# Collect texts per event
event_texts = (
    events_df
    .groupby("event_id")["clean_text"]
    .apply(list)
    .reset_index(name="texts")
)

# Merge texts into event_summary
event_summary = event_summary.merge(event_texts, on="event_id")

# %%
event_summary["risk"] = event_summary.apply(
    lambda row: detect_risk_level(
        row["texts"],
        row["locations"],
        row["message_count"]
    ),
    axis=1
)

event_summary[["event_id", "credibility", "risk"]]
# Out:
#     event_id credibility    risk
# 0          0        High    High
# 1          1        High    High
# 2          2        High    High
# 3          3        High    High
# 4          4        High    High
# 5          5        High  Medium
# 6          6      Medium    High
# 7          7        High    High
# 8          8        High    High
# 9          9        High    High
# 10        10      Medium     Low
# 11        11      Medium     Low
# 12        12        High     Low
# 13        13      Medium    High
# 14        14      Medium     Low
# 15        15      Medium     Low

# %%
def make_decision(credibility, risk):
    # High risk cases
    if risk == "High":
        if credibility in ["High", "Medium"]:
            return "ALERT"
        else:
            return "MONITOR"

    # Medium risk cases
    if risk == "Medium":
        if credibility == "High":
            return "MONITOR"
        else:
            return "MONITOR"

    # Low risk cases
    return "IGNORE"

# %%
event_summary["decision"] = event_summary.apply(
    lambda row: make_decision(row["credibility"], row["risk"]),
    axis=1
)

event_summary[["event_id", "credibility", "risk", "decision"]]
# Out:
#     event_id credibility    risk decision
# 0          0        High    High    ALERT
# 1          1        High    High    ALERT
# 2          2        High    High    ALERT
# 3          3        High    High    ALERT
# 4          4        High    High    ALERT
# 5          5        High  Medium  MONITOR
# 6          6      Medium    High    ALERT
# 7          7        High    High    ALERT
# 8          8        High    High    ALERT
# 9          9        High    High    ALERT
# 10        10      Medium     Low   IGNORE
# 11        11      Medium     Low   IGNORE
# 12        12        High     Low   IGNORE
# 13        13      Medium    High    ALERT
# 14        14      Medium     Low   IGNORE
# 15        15      Medium     Low   IGNORE

# %%
def credibility_score(message_count, sources):
    score = 0
    sources = set(sources)

    if "official" in sources:
        score += 40
    if "emergency" in sources:
        score += 30
    if "news" in sources:
        score += 10

    score += min(message_count * 5, 30)

    return min(score, 100)

# %%
def risk_score(risk_level):
    if risk_level == "High":
        return 85
    elif risk_level == "Medium":
        return 55
    else:
        return 25

# %%
event_summary["credibility_score"] = event_summary.apply(
    lambda row: credibility_score(row["message_count"], row["sources"]),
    axis=1
)

event_summary["risk_score"] = event_summary["risk"].apply(risk_score)

# %%
def build_event_timeline(event_messages):
    timeline = []

    for idx, row in event_messages.iterrows():
        stage = "Detected"

        if row["source"] in ["official", "emergency"]:
            stage = "Confirmed"
        elif idx > 0:
            stage = "Developing"

        timeline.append({
            "time": row["time"],
            "stage": stage,
            "source": row["source"]
        })

    return timeline

# %%
timelines = {}

for event_id in events_df["event_id"].unique():
    event_msgs = events_df[events_df["event_id"] == event_id].sort_values("time")
    timelines[event_id] = build_event_timeline(event_msgs)

# %%
event_summary["timeline"] = event_summary["event_id"].map(timelines)

# %%
final_output = event_summary[[
    "event_id",
    "locations",
    "message_count",
    "sources",
    "credibility",
    "credibility_score",
    "risk",
    "risk_score",
    "decision",
    "timeline"
]]

final_output
# Out:
#     event_id                                          locations  \
# 0          0  [Airport Road, Jaipur, Railway Station, Jaipur...
# 1          1  [Airport Road, Jaipur, Bus Stand, Jaipur, Rail...
# 2          2  [Airport Road, Jaipur, Bus Stand, Jaipur, Rail...
# 3          3  [Metro Station, Jaipur, Railway Station, Jaipu...
# 4          4  [Airport Road, Jaipur, Bus Stand, Jaipur, Metr...
# 5          5                          [University Road, Jaipur]
# 6          6  [Metro Station, Jaipur, Bus Stand, Jaipur, Vai...
# 7          7  [Bus Stand, Jaipur, Mansarovar, Jaipur, Univer...
# 8          8      [Airport Road, Jaipur, Metro Station, Jaipur]
# 9          9  [Airport Road, Jaipur, Bus Stand, Jaipur, Univ...
# 10        10                              [Civil Lines, Jaipur]
# 11        11                           [Vaishali Nagar, Jaipur]
# 12        12       [Vaishali Nagar, Jaipur, Mansarovar, Jaipur]
# 13        13       [Bus Stand, Jaipur, University Road, Jaipur]
# 14        14                               [Mansarovar, Jaipur]
# 15        15                                           [Jaipur]
#
#     message_count                              sources credibility  \
# 0              28  [news, social, emergency, official]        High
# 1              26        [social, official, emergency]        High
# 2              44        [social, emergency, official]        High
# 3              16                   [social, official]        High
# 4              10                   [social, official]        High
# 5              12             [news, social, official]        High
# 6               7                             [social]      Medium
# 7              13                           [official]        High
# 8               5                           [official]        High
# 9              16                   [social, official]        High
# 10              2                             [social]      Medium
# 11              4                             [social]      Medium
# 12              6                           [official]        High
# 13              2                             [social]      Medium
# 14              2                             [social]      Medium
# 15              2                   [social, official]      Medium
#
#     credibility_score    risk  risk_score decision  \
# 0                 100    High          85    ALERT
# 1                 100    High          85    ALERT
# 2                 100    High          85    ALERT
# 3                  70    High          85    ALERT
# 4                  70    High          85    ALERT
# 5                  80  Medium          55  MONITOR
# 6                  30    High          85    ALERT
# 7                  70    High          85    ALERT
# 8                  65    High          85    ALERT
# 9                  70    High          85    ALERT
# 10                 10     Low          25   IGNORE
# 11                 20     Low          25   IGNORE
# 12                 70     Low          25   IGNORE
# 13                 10    High          85    ALERT
# 14                 10     Low          25   IGNORE
# 15                 50     Low          25   IGNORE
#
#                                              timeline
# 0   [{'time': '10:25:00 AM', 'stage': 'Developing'...
# 1   [{'time': '10:35:00 AM', 'stage': 'Developing'...
# 2   [{'time': '10:55:00 AM', 'stage': 'Developing'...
# 3   [{'time': '11:05:00 AM', 'stage': 'Developing'...
# 4   [{'time': '10:00:00 AM', 'stage': 'Confirmed',...
# 5   [{'time': '10:05:00 AM', 'stage': 'Developing'...
# 6   [{'time': '10:15:00 AM', 'stage': 'Developing'...
# 7   [{'time': '10:20:00 AM', 'stage': 'Confirmed',...
# 8   [{'time': '10:30:00 AM', 'stage': 'Confirmed',...
# 9   [{'time': '10:45:00 AM', 'stage': 'Developing'...
# 10  [{'time': '11:35:00 AM', 'stage': 'Developing'...
# 11  [{'time': '12:05:00 PM', 'stage': 'Developing'...
# 12  [{'time': '10:00:00 PM', 'stage': 'Confirmed',...
# 13  [{'time': '3:45:00 PM', 'stage': 'Developing',...
# 14  [{'time': '11:15:00 PM', 'stage': 'Developing'...
# 15  [{'time': '4:25:00 PM', 'stage': 'Developing',...

# %%
# Convert dataframe to JSON
final_json = final_output.to_dict(orient="records")

final_json
# Out:
# [{'event_id': 0,
#   'locations': ['Airport Road, Jaipur',
#    'Railway Station, Jaipur',
#    'Bus Stand, Jaipur',
#    'Metro Station, Jaipur',
#    'City Mall, Jaipur',
#    'Civil Lines, Jaipur',
#    'Vaishali Nagar, Jaipur'],
#   'message_count': 28,
#   'sources': ['news', 'social', 'emergency', 'official'],
#   'credibility': 'High',
#   'credibility_score': 100,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:25:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '10:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '10:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:25:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:30:00 AM', 'stage': 'Developing', 'source': 'news'},
#    {'time': '11:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:15:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:20:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:05:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:50:00 PM', 'stage': 'Developing', 'source': 'news'},
#    {'time': '4:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '4:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '5:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '5:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '5:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '6:00:00 PM', 'stage': 'Developing', 'source': 'news'},
#    {'time': '7:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '7:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '8:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:00:00 AM', 'stage': 'Detected', 'source': 'social'},
#    {'time': '9:04:00 AM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '9:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:10:00 PM', 'stage': 'Confirmed', 'source': 'official'}]},
#  {'event_id': 1,
#   'locations': ['Airport Road, Jaipur',
#    'Bus Stand, Jaipur',
#    'Railway Station, Jaipur',
#    'Metro Station, Jaipur',
#    'University Road, Jaipur',
#    'City Mall, Jaipur',
#    'Civil Lines, Jaipur',
#    'NH-21, Jaipur'],
#   'message_count': 26,
#   'sources': ['social', 'official', 'emergency'],
#   'credibility': 'High',
#   'credibility_score': 100,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:35:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '10:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '10:40:00 AM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '10:40:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:40:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '12:25:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:30:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:40:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:25:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:30:00 AM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '1:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:00:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '3:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '4:00:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '5:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '5:20:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '7:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '7:20:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '8:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '8:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:10:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:14:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:30:00 PM', 'stage': 'Confirmed', 'source': 'emergency'}]},
#  {'event_id': 2,
#   'locations': ['Airport Road, Jaipur',
#    'Bus Stand, Jaipur',
#    'Railway Station, Jaipur',
#    'Mansarovar, Jaipur',
#    'Metro Station, Jaipur',
#    'University Road, Jaipur',
#    'City Mall, Jaipur',
#    'Civil Lines, Jaipur',
#    'NH-21, Jaipur'],
#   'message_count': 44,
#   'sources': ['social', 'emergency', 'official'],
#   'credibility': 'High',
#   'credibility_score': 100,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:55:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '10:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:00:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:00:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '11:45:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:50:00 AM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '11:50:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '11:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:00:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:20:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '12:45:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:50:00 AM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '12:50:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '1:35:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:10:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '2:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:20:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '3:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '3:10:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '3:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '3:40:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '4:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '4:50:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '5:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '5:40:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '6:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '6:20:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '6:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '6:50:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '7:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '7:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '7:40:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '8:40:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '8:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '8:50:00 PM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '9:20:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:23:00 AM', 'stage': 'Confirmed', 'source': 'emergency'},
#    {'time': '9:30:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:35:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:50:00 PM', 'stage': 'Confirmed', 'source': 'emergency'}]},
#  {'event_id': 3,
#   'locations': ['Metro Station, Jaipur',
#    'Railway Station, Jaipur',
#    'Mansarovar, Jaipur',
#    'Civil Lines, Jaipur'],
#   'message_count': 16,
#   'sources': ['social', 'official'],
#   'credibility': 'High',
#   'credibility_score': 70,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '11:05:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '11:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:10:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '2:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '4:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '5:00:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '6:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '8:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:00:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:40:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:46:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:55:00 PM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 4,
#   'locations': ['Airport Road, Jaipur',
#    'Bus Stand, Jaipur',
#    'Metro Station, Jaipur'],
#   'message_count': 10,
#   'sources': ['social', 'official'],
#   'credibility': 'High',
#   'credibility_score': 70,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:00:00 AM',
#     'stage': 'Confirmed',
#     'source': 'official'},
#    {'time': '11:15:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '11:20:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:20:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '2:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '2:40:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '6:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '6:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:55:00 AM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 5,
#   'locations': ['University Road, Jaipur'],
#   'message_count': 12,
#   'sources': ['news', 'social', 'official'],
#   'credibility': 'High',
#   'credibility_score': 80,
#   'risk': 'Medium',
#   'risk_score': 55,
#   'decision': 'MONITOR',
#   'timeline': [{'time': '10:05:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '10:05:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '10:10:00 AM', 'stage': 'Developing', 'source': 'news'},
#    {'time': '10:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:55:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:00:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '3:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '3:20:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '7:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '8:00:00 PM', 'stage': 'Confirmed', 'source': 'official'}]},
#  {'event_id': 6,
#   'locations': ['Metro Station, Jaipur',
#    'Bus Stand, Jaipur',
#    'Vaishali Nagar, Jaipur',
#    'City Mall, Jaipur'],
#   'message_count': 7,
#   'sources': ['social'],
#   'credibility': 'Medium',
#   'credibility_score': 30,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:15:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '10:15:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:05:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:15:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '6:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '8:05:00 PM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 7,
#   'locations': ['Bus Stand, Jaipur',
#    'Mansarovar, Jaipur',
#    'University Road, Jaipur',
#    'Metro Station, Jaipur',
#    'City Mall, Jaipur',
#    'Civil Lines, Jaipur',
#    'Vaishali Nagar, Jaipur'],
#   'message_count': 13,
#   'sources': ['official'],
#   'credibility': 'High',
#   'credibility_score': 70,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:20:00 AM',
#     'stage': 'Confirmed',
#     'source': 'official'},
#    {'time': '10:20:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:20:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '11:40:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:10:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:20:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:40:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '3:00:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '4:20:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '5:50:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '7:00:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '8:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '9:20:00 PM', 'stage': 'Confirmed', 'source': 'official'}]},
#  {'event_id': 8,
#   'locations': ['Airport Road, Jaipur', 'Metro Station, Jaipur'],
#   'message_count': 5,
#   'sources': ['official'],
#   'credibility': 'High',
#   'credibility_score': 65,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:30:00 AM',
#     'stage': 'Confirmed',
#     'source': 'official'},
#    {'time': '1:10:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:50:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '5:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '8:20:00 PM', 'stage': 'Confirmed', 'source': 'official'}]},
#  {'event_id': 9,
#   'locations': ['Airport Road, Jaipur',
#    'Bus Stand, Jaipur',
#    'University Road, Jaipur',
#    'City Mall, Jaipur',
#    'Civil Lines, Jaipur',
#    'NH-21, Jaipur'],
#   'message_count': 16,
#   'sources': ['social', 'official'],
#   'credibility': 'High',
#   'credibility_score': 70,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '10:45:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '10:45:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '10:50:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:35:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '12:40:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '12:55:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '1:40:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '3:50:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '4:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '4:40:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '5:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '6:40:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '7:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '8:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:35:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '9:40:00 PM', 'stage': 'Confirmed', 'source': 'official'}]},
#  {'event_id': 10,
#   'locations': ['Civil Lines, Jaipur'],
#   'message_count': 2,
#   'sources': ['social'],
#   'credibility': 'Medium',
#   'credibility_score': 10,
#   'risk': 'Low',
#   'risk_score': 25,
#   'decision': 'IGNORE',
#   'timeline': [{'time': '11:35:00 AM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '2:55:00 PM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 11,
#   'locations': ['Vaishali Nagar, Jaipur'],
#   'message_count': 4,
#   'sources': ['social'],
#   'credibility': 'Medium',
#   'credibility_score': 20,
#   'risk': 'Low',
#   'risk_score': 25,
#   'decision': 'IGNORE',
#   'timeline': [{'time': '12:05:00 PM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '12:55:00 AM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '3:25:00 PM', 'stage': 'Developing', 'source': 'social'},
#    {'time': '7:45:00 PM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 12,
#   'locations': ['Vaishali Nagar, Jaipur', 'Mansarovar, Jaipur'],
#   'message_count': 6,
#   'sources': ['official'],
#   'credibility': 'High',
#   'credibility_score': 70,
#   'risk': 'Low',
#   'risk_score': 25,
#   'decision': 'IGNORE',
#   'timeline': [{'time': '10:00:00 PM',
#     'stage': 'Confirmed',
#     'source': 'official'},
#    {'time': '12:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '1:00:00 AM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '3:30:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '6:10:00 PM', 'stage': 'Confirmed', 'source': 'official'},
#    {'time': '7:50:00 PM', 'stage': 'Confirmed', 'source': 'official'}]},
#  {'event_id': 13,
#   'locations': ['Bus Stand, Jaipur', 'University Road, Jaipur'],
#   'message_count': 2,
#   'sources': ['social'],
#   'credibility': 'Medium',
#   'credibility_score': 10,
#   'risk': 'High',
#   'risk_score': 85,
#   'decision': 'ALERT',
#   'timeline': [{'time': '3:45:00 PM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '6:35:00 PM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 14,
#   'locations': ['Mansarovar, Jaipur'],
#   'message_count': 2,
#   'sources': ['social'],
#   'credibility': 'Medium',
#   'credibility_score': 10,
#   'risk': 'Low',
#   'risk_score': 25,
#   'decision': 'IGNORE',
#   'timeline': [{'time': '11:15:00 PM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '4:15:00 PM', 'stage': 'Developing', 'source': 'social'}]},
#  {'event_id': 15,
#   'locations': ['Jaipur'],
#   'message_count': 2,
#   'sources': ['social', 'official'],
#   'credibility': 'Medium',
#   'credibility_score': 50,
#   'risk': 'Low',
#   'risk_score': 25,
#   'decision': 'IGNORE',
#   'timeline': [{'time': '4:25:00 PM',
#     'stage': 'Developing',
#     'source': 'social'},
#    {'time': '4:30:00 PM', 'stage': 'Confirmed', 'source': 'official'}]}]

# %%
import json

with open("final_events.json", "w") as f:
    json.dump(final_json, f, indent=4)

print("final_events.json saved successfully")
# Out:
# final_events.json saved successfully
